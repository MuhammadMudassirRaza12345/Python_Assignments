# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

class Complex:
    def __init__(self, real=0, imaginary=0):
        self.real=real
        self.imaginary=imaginary
        
    def __add__(self,no):
        x = self.real + no.real
        y = self.imaginary + no.imaginary
        return Complex(x,y)
        
#     def __sub__(self, no):
        
#     def __mul__(self, no):

#     def __truediv__(self, no):

#     def mod(self):

    # def __str__(self):
    #     if self.imaginary == 0:
    #         result = "%.2f+0.00i" % (self.real)
    #     elif self.real == 0:
    #         if self.imaginary >= 0:
    #             result = "0.00+%.2fi" % (self.imaginary)
    #         else:
    #             result = "0.00-%.2fi" % (abs(self.imaginary))
    #     elif self.imaginary > 0:
    #         result = "%.2f+%.2fi" % (self.real, self.imaginary)
    #     else:
    #         result = "%.2f-%.2fi" % (self.real, abs(self.imaginary))
    #     return result

# if __name__ == '__main__':

# %%
p1=Complex(1, 2)
p2=Complex(2, 3)
print(p1+p2)
# Out:
# <__main__.Complex object at 0x000001B6D3D7C730>

# %%
class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
#         return self.__str__()

    def __str__(self):
        return f"({self.x},{self.y})"

    def __add__(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x, y)

    def __sub__(self, other):
        x = self.x - other.x
        y = self.y - other.y
        return Point(x, y)  

    def __mul__(self, other):
        x = self.x * other.x+self.y * other.y*-1
        y = self.x * other.y+self.y * other.x
        return Point(x, y)
#       return Complex(self.a*rhs.a+self.b*rhs.b*(-1), self.b*rhs.a+self.a*rhs.b)
# p1=Point(2, 1)
# p2=Point(5, 6)

    def __truediv__(self, other):
        x = self.x / other.x
        y = self.y / other.y
        return Point(x, y)    
    
#     def __div__(self, rhs):
#         sr, si, oor, oi = self.a, self.b, rhs.a, rhs.b # short forms
#         r = float(oor**2 + oi**2)
#         return Complex((sr*oor+si*oi)/r, (si*oor-sr*oi)/r)

#     def __str__(self):
#         if self.y == 0:
#             result = "%.2f+0.00i" % (self.x)
            
#         elif self.x == 0:
#             if self.y >= 0:
#                 result = "0.00+%.2fi" % (self.y)
#             else:
#                 result = "0.00-%.2fi" % (abs(self.y))
#         elif self.y > 0:
#             result = "%.2f+%.2fi" % (self.x, self.y)
#         else:
#             result = "%.2f-%.2fi" % (self.x, abs(self.y))
        return result     

    # def __mod__(self, other):
    #     x = self.x % other.x
    #     y = self.y % other.y
    #     return Point(x, y)

# %%
p1=Point(2, 1)
p2=Point(5, 6)
print(p1+p2)
print(p1 - p2)
print(p1*p2)
print(p1/p2)

# print(p1%p2)
# p2.__mod__()
# Out:
# (7,7)
# (-3,-5)
# (4,17)
# (0.4,0.16666666666666666)

# %%
import math 
class Complex:
    def __init__(self, real=0, imaginary=0):
        self.real=real
        self.imaginary=imaginary
        
    def __add__(self,no):
        real = self.real +  no.real
        imaginary = self.imaginary +  no.imaginary
        return Complex(real,imaginary) 
        # print(real,imaginary)   
    
# p1=Complex(1, 2)
# print(p1)
# # p2=Complex(2, 3)

# %%
p1=Complex(1, 2)
p2=Complex(2, 3)
print(p1+p2)
# Out:
# <__main__.Complex object at 0x000001B6D3D7CB80>
